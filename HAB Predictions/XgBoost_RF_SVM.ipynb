# %%
import numpy as np
import matplotlib
import pandas as pd
import tensorflow as tf

dataset = pd.read_csv('/Users/wzhang/Downloads/lake_erie_habs_W4_6_8_9_12_13_16_2013-2020.xlsx - HAB_data (1).csv')

train = dataset.iloc[:743,:]
test = dataset.iloc[743:,:]
print(train)
print(test)
X_train = pd.DataFrame(train.iloc[:,4:15].values)
Y_train = train.iloc[:,16:].values
print(X_train.shape)
print(Y_train.shape)
X_test = pd.DataFrame(test.iloc[:,4:15].values)
Y_test = test.iloc[:,16:].values
print(X_test.shape)
print(Y_test.shape)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
#           Date  Site  Latitude (decimal deg)  Longitude (decimal deg)  \
# 0    5/29/2013   WE6                 41.7134                 -83.3804
# 1    5/29/2013   WE8                 41.8343                 -83.3633
# 2    5/29/2013   WE4                 41.8267                 -83.1930
# 3    6/10/2013   WE6                 41.7144                 -83.3805
# 4    6/10/2013   WE8                 41.8353                 -83.3631
# ..         ...   ...                     ...                      ...
# 738  10/7/2019  WE16                 41.6599                 -83.1467
# 739  10/7/2019  WE13                 41.7428                 -83.1354
# 740  10/7/2019  WE12                 41.7023                 -83.2639
# 741  10/7/2019   WE4                 41.8270                 -83.1949
# 742  6/16/2020   WE6                 41.7054                 -83.3864
#
#      Secchi Depth (m)  CTD Temperature (°C)  \
# 0                1.60                  18.5
# 1                1.00                  20.3
# 2                1.50                  19.8
# 3                0.50                  20.7
# 4                0.70                  23.5
# ..                ...                   ...
# 738              1.00                  18.2
# 739              1.25                  18.2
# 740              1.25                  18.5
# 741              1.50                  17.2
# 742              0.20                  20.3
#
#      CTD Specific Conductivity (µS/cm)  CTD Dissolved Oxygen (mg/L)  \
# 0                                391.3                         7.60
# 1                                379.8                         7.60
# 2                                296.2                         7.60
# 3                                341.2                         7.60
# 4                                301.3                         7.50
# ..                                 ...                          ...
# 738                              304.3                         6.50
# 739                              265.1                         7.50
# 740                              251.6                         7.20
# 741                              221.3                         7.50
# 742                              275.4                         7.78
#
#      Turbidity (NTU)  Total Phosphorus (µg P/L)  \
# 0               8.44                      48.51
# 1               9.98                      37.85
# 2               4.36                      15.58
# 3              21.50                      58.18
# 4              15.70                      48.33
# ..               ...                        ...
# 738             9.96                      45.09
# 739             3.66                      26.28
# 740            10.60                      31.56
# 741             4.04                      13.42
# 742            75.20                      29.78
#
#      Total Dissolved Phosphorus (µg P/L)  Ammonia (µg N/L)  \
# 0                                  33.01             62.95
# 1                                  18.68             40.25
# 2                                   4.70             13.07
# 3                                   8.66              7.34
# 4                                  15.90             23.02
# ..                                   ...               ...
# 738                                29.05             39.64
# 739                                 8.33              7.28
# 740                                 9.42              6.07
# 741                                 5.34             25.19
# 742                                 5.76             18.23
#
#      Nitrate + Nitrite (mg N/L)  Particulate Organic Carbon (mg/L)  \
# 0                         2.420                               0.42
# 1                         2.110                               0.45
# 2                         0.900                               0.32
# 3                         1.340                               1.22
# 4                         1.060                               0.69
# ..                          ...                                ...
# 738                       0.378                               0.55
# 739                       0.321                               0.63
# 740                       0.161                               0.84
# 741                       0.245                               0.26
# 742                       1.047                               0.41
#
#      Particulate Organic Nitrogen (mg/L)  Total Suspended Solids (mg/L)  \
# 0                                   0.06                          12.80
# 1                                   0.07                          10.07
# 2                                   0.06                           5.47
# 3                                   0.18                          24.50
# 4                                   0.10                          17.77
# ..                                   ...                            ...
# 738                                 0.07                           9.72
# 739                                 0.10                           6.47
# 740                                 0.14                          13.20
# 741                                 0.06                           4.88
# 742                                 0.08                           5.48
#
#      Extracted Chlorophyll a (µg/L)
# 0                              2.15
# 1                              3.65
# 2                              4.34
# 3                             23.39
# 4                              5.30
# ..                              ...
# 738                            6.29
# 739                           19.70
# 740                           22.88
# 741                            2.06
# 742                            1.46
#
# [743 rows x 17 columns]
#           Date  Site  Latitude (decimal deg)  Longitude (decimal deg)  \
# 743  6/16/2020   WE8                 41.8349                 -83.3587
# 744  6/16/2020   WE9                 41.7176                 -83.4225
# 745  6/16/2020  WE12                 41.7026                 -83.2527
# 746  6/29/2020   WE6                 41.7057                 -83.3839
# 747  6/29/2020   WE8                 41.8343                 -83.3579
# ..         ...   ...                     ...                      ...
# 834  10/5/2020   WE9                 41.7176                 -83.4239
# 835  10/5/2020  WE16                 41.6599                 -83.1468
# 836  10/5/2020  WE13                 41.7436                 -83.1526
# 837  10/5/2020  WE12                 41.7040                 -83.2552
# 838  10/5/2020   WE4                 41.8267                 -83.1947
#
#      Secchi Depth (m)  CTD Temperature (°C)  \
# 743               0.2                  20.6
# 744               0.2                  21.7
# 745               0.2                  20.2
# 746               1.1                  24.9
# 747               1.6                  24.3
# ..                ...                   ...
# 834               0.8                  14.4
# 835               1.8                  15.4
# 836               1.8                  15.7
# 837               1.0                  15.2
# 838               3.5                  15.7
#
#      CTD Specific Conductivity (µS/cm)  CTD Dissolved Oxygen (mg/L)  \
# 743                              309.0                         7.68
# 744                              442.4                         7.02
# 745                              259.3                         7.69
# 746                              353.0                         8.68
# 747                              301.0                         9.64
# ..                                 ...                          ...
# 834                              313.1                         9.00
# 835                              249.6                         8.90
# 836                              221.3                         8.97
# 837                              258.4                         9.07
# 838                              226.4                         8.54
#
#      Turbidity (NTU)  Total Phosphorus (µg P/L)  \
# 743            57.20                      22.70
# 744            41.30                      52.74
# 745            35.80                      90.23
# 746             6.80                      31.78
# 747             5.38                      26.70
# ..               ...                        ...
# 834             9.38                      47.68
# 835             3.48                      22.20
# 836             2.30                      14.30
# 837             7.24                      28.96
# 838             1.27                      13.01
#
#      Total Dissolved Phosphorus (µg P/L)  Ammonia (µg N/L)  \
# 743                                 7.86             36.56
# 744                                13.00             59.00
# 745                                25.36             45.80
# 746                                 7.23             28.74
# 747                                 8.87             44.73
# ..                                   ...               ...
# 834                                18.77             20.71
# 835                                 8.86             20.53
# 836                                 5.21             12.07
# 837                                 9.31              2.89
# 838                                 5.44             23.46
#
#      Nitrate + Nitrite (mg N/L)  Particulate Organic Carbon (mg/L)  \
# 743                       0.707                               0.56
# 744                       0.701                               1.97
# 745                       1.870                               0.58
# 746                       0.914                               0.52
# 747                       0.807                               0.66
# ..                          ...                                ...
# 834                       0.069                               0.98
# 835                       0.105                               0.46
# 836                       0.249                               0.27
# 837                       0.002                               0.83
# 838                       0.271                               0.19
#
#      Particulate Organic Nitrogen (mg/L)  Total Suspended Solids (mg/L)  \
# 743                                 0.15                           2.24
# 744                                 0.42                           8.00
# 745                                 0.07                           9.48
# 746                                 0.11                           5.48
# 747                                 0.15                           2.47
# ..                                   ...                            ...
# 834                                 0.17                           9.56
# 835                                 0.09                           6.13
# 836                                 0.04                           3.56
# 837                                 0.09                           8.39
# 838                                 0.02                           1.76
#
#      Extracted Chlorophyll a (µg/L)
# 743                           29.90
# 744                           29.90
# 745                            1.53
# 746                           12.71
# 747                           21.54
# ..                              ...
# 834                            9.98
# 835                            6.36
# 836                            3.91
# 837                            9.65
# 838                            1.74
#
# [96 rows x 17 columns]
# (743, 11)
# (743, 1)
# (96, 11)
# (96, 1)

# %%
from keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Dropout, Dense, BatchNormalization, GRU, LayerNormalization, MultiHeadAttention,TimeDistributed, Input, Flatten
from sklearn.ensemble import RandomForestRegressor

# %%
def create_rf():
    # Initialize Random Forest regressor
    rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

    # Train the model
    rf_model.fit(X_train, Y_train)
    return rf_model

# %%
from sklearn.svm import SVR
def create_SVM():
    # Initialize SVM regressor
    svm_model = SVR(kernel='rbf', C=10000, gamma='scale')

    # Train the model
    svm_model.fit(X_train, Y_train)
    return svm_model

# %%
rf = create_rf()
svm = create_SVM()

# ridge = create_ridge()
# svm = create_SVM()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/utils/validation.py:1310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from tensorflow.keras.layers import concatenate


# gruPredict = gru.predict(X_train)
# lassoPredict = lasso.predict(X_train)
# lstmPredict = lstm.predict(X_train)
rfPredict = rf.predict(X_train)
svmPredict = svm.predict(X_train)
# ridgePredict = ridge.predict(X_train)
# svmPredict = svm.predict(X_train)
# rfPredict = rf.predict(X_train)
# lassoPredict.resize(671,1)
rfPredict.resize(743,1)
svmPredict.resize(743,1)
# svmPredict.resize(671,1)
trainData = concatenate([rfPredict,svmPredict])

# %%
import xgboost as xgb

# Create regression matrices
dtrain_reg = xgb.DMatrix(trainData, Y_train, enable_categorical=True)

# %%
params = {"objective": "reg:squarederror", "tree_method": "gpu_hist"}
n = 100
model = xgb.train(
   params=params,
   dtrain=dtrain_reg,
   num_boost_round=n,
)
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[10], line 3
#       1 params = {"objective": "reg:squarederror", "tree_method": "gpu_hist"}
#       2 n = 100
# ----> 3 model = xgb.train(
#       4    params=params,
#       5    dtrain=dtrain_reg,
#       6    num_boost_round=n,
#       7 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/core.py:2100, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
# -> 2100     _check_call(
#    2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/core.py:284, in _check_call(ret)
#     273 """Check the return value of C API call
#     274
#     275 This function will raise exception when error occurs.
#    (...)
#     281     return value from API calls
#     282 """
#     283 if ret != 0:
# --> 284     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: [14:28:49] /Users/runner/work/xgboost/xgboost/src/gbm/../common/common.h:174: XGBoost version not compiled with GPU support.
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001518d1c35 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x0000000151b106f0 xgboost::gbm::GBTree::Configure(std::__1::vector<std::__1::pair<std::__1::basic_string<char, std::__1::char_traits<char>, std::__1::allocator<char>>, std::__1::basic_string<char, std::__1::char_traits<char>, std::__1::allocator<char>>>, std::__1::allocator<std::__1::pair<std::__1::basic_string<char, std::__1::char_traits<char>, std::__1::allocator<char>>, std::__1::basic_string<char, std::__1::char_traits<char>, std::__1::allocator<char>>>>> const&) + 1392
#   [bt] (2) 3   libxgboost.dylib                    0x0000000151b33d66 xgboost::LearnerConfiguration::Configure() + 1094
#   [bt] (3) 4   libxgboost.dylib                    0x0000000151b33fbb xgboost::LearnerImpl::UpdateOneIter(int, std::__1::shared_ptr<xgboost::DMatrix>) + 107
#   [bt] (4) 5   libxgboost.dylib                    0x00000001518f3507 XGBoosterUpdateOneIter + 135
#   [bt] (5) 6   libffi.dylib                        0x00007ff829cbe8c2 ffi_call_unix64 + 82
#   [bt] (6) 7   ???                                 0x00007ff7bc494590 0x0 + 140701992568208

# %%
# gruPredictTest = gru.predict(X_test)
# lassoPredictTest = lasso.predict(X_test)
# lstmPredictTest = lstm.predict(X_test)
rfPredictTest = rf.predict(X_test)
svmPredictTest = svm.predict(X_test)
# ridgePredictTest = ridge.predict(X_test)
# svmPredictTest = svm.predict(X_test)
# svmPredictTest.resize(168,1)
# svmPredictTest.resize(96,1)
# lassoPredictTest.resize(168,1)
rfPredictTest.resize(96,1)
svmPredictTest.resize(96,1)
testData = concatenate([rfPredictTest, svmPredictTest])

# %%
dtest_reg = xgb.DMatrix(testData, Y_test, enable_categorical=True)

# %%
res = model.predict(dtest_reg)
print(res)

# %%
from sklearn.metrics import r2_score 
r2 = r2_score(Y_test, res) 
print(r2)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(Y_test,res)
print(mae)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(Y_test,res)
print(mape)

# %%
from sklearn.metrics import root_mean_squared_error
rmse = root_mean_squared_error(Y_test,res)
print(rmse)
